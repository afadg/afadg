# %% [markdown]
# <a href="https://colab.research.google.com/github/afadg/afadg/blob/gh-pages/YAPAY_ZEKA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input("lütfen adınızı giriniz:")

# %%
input("lütfen şifrenızı giriniz:")

# %%
kullanıcı_adı = input("lütfen adınızı giriniz")

# %%
usenam=print(kullanıcı_adı)

# %%
username = input("lütfen kullanı adı giriniz")

# %%
password = input("lütfen şifrenizi giriniz ")
# Out:
# lütfen şifrenizi giriniz orçun

# %%
kullanıcı_adı = "orçun
şifrem ="yot55768476
username = input("lütfen kullanıçı adınızı giriniz")
password = input("lütfen şifrenizi giriniz")

if password != şifre: 
print("hatalı şifre gidiniz!")
