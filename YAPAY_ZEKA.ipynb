# %% [markdown]
# <a href="https://colab.research.google.com/github/afadg/afadg/blob/gh-pages/YAPAY_ZEKA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kayıtlı_şifre = 3750



for giriş_siyisi in range(1,4):
  girilen_şifre  = int(input("şifrenizi giriniz: "))
 
  if girilen_şifre == kayıtlı_şifre:
     print("hoşgeldiniz!")
  break


else:
      print("Hatalı şifre girdiniz!\n")
      if giriş_sayisi == 3:
         print("kartınız bloke olmuştur!")
